# %% [markdown]
# # **Hitung Jarak Antar Data**

# %% [markdown]
# ## Rubah nilai jarak data ordinal ke numerik

# %% [markdown]
# ## Rubah nilai jarak data kategorikal ke numerik

# %% [markdown]
# ## Rubah nilai jarak data biner ke numerik
